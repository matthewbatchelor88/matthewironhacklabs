# %% [markdown]
# ## From the Billboard Top 100, create a data frame of song and artist
# ## Export dataframe to csv called billboard_hot_100_csv

# %%
# import libraries

from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
url ="https://www.billboard.com/charts/hot-100/" 
response = requests.get(url)
soup = BeautifulSoup(response.content, "html.parser")

# %%
# creating list and adding songs 

songs = []
for song in soup.select("div li h3.c-title"):
    songs.append(song.get_text(strip=True))

# %%
songs
# Out:
# ['Lovin On Me',
#  'Lose Control',
#  'Beautiful Things',
#  'Cruel Summer',
#  'Snooze',
#  'I Remember Everything',
#  'Greedy',
#  'Fast Car',
#  'Agora Hills',
#  'Flowers',
#  'Stick Season',
#  'Water',
#  'Hiss',
#  'Redrum',
#  'Last Night',
#  "Thinkin' Bout Me",
#  'Paint The Town Red',
#  "Is It Over Now? (Taylor's Version) [From The Vault]",
#  'Never Lose Me',
#  'What Was I Made For?',
#  'Yes, And?',
#  'Houdini',
#  'Selfish',
#  'Pretty Little Poison',
#  'La Diabla',
#  'Where The Wild Things Are',
#  'Everybody',
#  'Made For Me',
#  'Vampire',
#  'The Painter',
#  'White Horse',
#  'Rich Baby Daddy',
#  'On My Mama',
#  'Exes',
#  'Wild Ones',
#  'Feather',
#  'Dance The Night',
#  'Bandit',
#  'Need A Favor',
#  'Save Me',
#  'Fukumean',
#  'Fast Car',
#  'Lil Boo Thang',
#  'World On Fire',
#  'Good Good',
#  'Truck Bed',
#  'First Person Shooter',
#  'Surround Sound',
#  'Strangers',
#  'My Love Mine All Mine',
#  'Spin You Around (1/24)',
# ...

# %%
# creating list and adding artists

artists = []
for artist in soup.select("span.c-label.a-no-trucate.a-font-primary-s"):
    artists.append(artist.get_text(strip=True))

# %%
artists
# Out:
# ['Jack Harlow',
#  'Teddy Swims',
#  'Benson Boone',
#  'Taylor Swift',
#  'SZA',
#  'Zach Bryan Featuring Kacey Musgraves',
#  'Tate McRae',
#  'Luke Combs',
#  'Doja Cat',
#  'Miley Cyrus',
#  'Noah Kahan',
#  'Tyla',
#  'Megan Thee Stallion',
#  '21 Savage',
#  'Morgan Wallen',
#  'Morgan Wallen',
#  'Doja Cat',
#  'Taylor Swift',
#  'Flo Milli',
#  'Billie Eilish',
#  'Ariana Grande',
#  'Dua Lipa',
#  'Justin Timberlake',
#  'Warren Zeiders',
#  'Xavi',
#  'Luke Combs',
#  'Nicki Minaj Featuring Lil Uzi Vert',
#  'Muni Long',
#  'Olivia Rodrigo',
#  'Cody Johnson',
#  'Chris Stapleton',
#  'Drake Featuring Sexyy Red & SZA',
#  'Victoria Monet',
#  'Tate McRae',
#  'Jessie Murph & Jelly Roll',
#  'Sabrina Carpenter',
#  'Dua Lipa',
#  'Don Toliver',
#  'Jelly Roll',
#  'Jelly Roll With Lainey Wilson',
#  'Gunna',
#  'Tracy Chapman',
#  'Paul Russell',
#  'Nate Smith',
#  'Usher, Summer Walker & 21 Savage',
#  'HARDY',
#  'Drake Featuring J. Cole',
# ...

# %%
soup.select("span.c-label")
# Out:
# [<span class="c-label a-font-primary-bold-xxl lrv-u-padding-lr-1 lrv-u-padding-t-025">
#
#  	2
#  </span>,
#  <span class="c-label a-font-primary-bold-xxl lrv-u-padding-lr-1 lrv-u-padding-t-025">
#
#  	5
#  </span>,
#  <span class="c-label a-font-primary-bold-xxl lrv-u-padding-lr-1 lrv-u-padding-t-025">
#
#  	13
#  </span>,
#  <span class="c-label a-font-primary-bold-l u-font-size-32@tablet u-letter-spacing-0080@tablet">
#
#  	1
#  </span>,
#  <span class="c-label a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only u-font-size-20@tablet">
#
#  	Jack Harlow
#  </span>,
#  <span class="c-label a-font-primary-bold-l a-font-primary-m@mobile-max u-font-weight-normal@mobile-max lrv-u-padding-tb-050@mobile-max u-font-size-32@tablet">
#
#  	2
#  </span>,
# ...

# %%
# create dataframe 

billboard_100_df = pd.DataFrame({"songs":songs, "artists":artists})
billboard_100_df
# Out:
#                 songs                      artists
# 0         Lovin On Me                  Jack Harlow
# 1        Lose Control                  Teddy Swims
# 2    Beautiful Things                 Benson Boone
# 3        Cruel Summer                 Taylor Swift
# 4              Snooze                          SZA
# ..                ...                          ...
# 95           Worth It         Offset & Don Toliver
# 96  Northern Attitude       Noah Kahan With Hozier
# 97    Scared To Start              Michael Marcagi
# 98         First Love  Oscar Ortiz X Edgardo Nunez
# 99      Where It Ends             Bailey Zimmerman
#
# [100 rows x 2 columns]

# %%
# Export the DataFrame to a CSV file
billboard_100_df.to_csv('billboard__hot_100_df.csv', index=False)
